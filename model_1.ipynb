# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Requirement already satisfied: sklearn in c:\users\sampo\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied: scikit-learn in c:\users\sampo\anaconda3\lib\site-packages (from sklearn) (0.24.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\sampo\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.0.1)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\sampo\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.20.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\sampo\anaconda3\lib\site-packages (from scikit-learn->sklearn) (2.1.0)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\sampo\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.6.2)

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in c:\users\sampo\anaconda3\lib\site-packages (1.0.1)

# %%
import pandas as pd
import numpy as np

# Sklearn Packages
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier

# Sklearn Evaluation Metrics
from sklearn import metrics
from sklearn.metrics import mean_squared_error, precision_score, confusion_matrix, accuracy_score

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
#df = pd.read_csv("cumulative.csv")

index = df.index
number_of_rows = len(index)
print(number_of_rows)
# Out:
# 6991

# %%
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')

index = df.index
number_of_rows = len(index)
print(number_of_rows)
# Out:
# 6991

# %%
# Visualizes all the columns
pd.set_option('display.max_columns', None)

# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  koi_time0bk_err2  koi_impact  koi_impact_err1  \
# 0          0.003520         -0.003520       0.586            0.059
# 1          0.000581         -0.000581       0.969            5.126
# 2          0.000115         -0.000115       1.276            0.115
# 3          0.001130         -0.001130       0.701            0.235
# 4          0.001900         -0.001900       0.762            0.139
#
#    koi_impact_err2  koi_duration  koi_duration_err1  koi_duration_err2  \
# 0           -0.443       4.50700            0.11600           -0.11600
# 1           -0.077       1.78220            0.03410           -0.03410
# 2           -0.092       2.40641            0.00537           -0.00537
# 3           -0.478       1.65450            0.04200           -0.04200
# 4           -0.532       3.14020            0.06730           -0.06730
#
#    koi_depth  koi_depth_err1  koi_depth_err2  koi_prad  koi_prad_err1  \
# 0      874.8            35.5           -35.5      2.83           0.32
# 1    10829.0           171.0          -171.0     14.60           3.92
# 2     8079.2            12.8           -12.8     33.46           8.50
# 3      603.3            16.9           -16.9      2.75           0.88
# 4      686.0            18.7           -18.7      2.77           0.90
#
#    koi_prad_err2  koi_teq  koi_insol  koi_insol_err1  koi_insol_err2  \
# 0          -0.19      443       9.11            2.87           -1.62
# 1          -1.31      638      39.30           31.04          -10.49
# 2          -2.83     1395     891.96          668.95         -230.35
# 3          -0.35     1406     926.16          874.33         -314.24
# 4          -0.30     1160     427.65          420.33         -136.70
#
#    koi_model_snr  koi_tce_plnt_num  koi_steff  koi_steff_err1  koi_steff_err2  \
# 0           25.8                 2       5455              81             -81
# 1           76.3                 1       5853             158            -176
# 2          505.6                 1       5805             157            -174
# 3           40.9                 1       6031             169            -211
# 4           40.2                 2       6046             189            -232
#
#    koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  koi_srad_err1  \
# 0      4.467           0.064          -0.096     0.927          0.105
# 1      4.544           0.044          -0.176     0.868          0.233
# 2      4.564           0.053          -0.168     0.791          0.201
# 3      4.438           0.070          -0.210     1.046          0.334
# 4      4.486           0.054          -0.229     0.972          0.315
#
#    koi_srad_err2         ra        dec  koi_kepmag
# 0         -0.061  291.93423  48.141651      15.347
# 1         -0.078  297.00482  48.134129      15.436
# 2         -0.067  285.53461  48.285210      15.597
# 3         -0.133  288.75488  48.226200      15.509
# 4         -0.105  296.28613  48.224670      15.714

# %%
index = df.index
number_of_rows = len(index)
print(number_of_rows)
# Out:
# 6991

# %%
df.koi_disposition.unique()
# Out:
# array(['CONFIRMED', 'FALSE POSITIVE', 'CANDIDATE'], dtype=object)

# %%
# Analysing type of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6991 entries, 0 to 6990
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   koi_disposition    6991 non-null   object
#  1   koi_fpflag_nt      6991 non-null   int64
#  2   koi_fpflag_ss      6991 non-null   int64
#  3   koi_fpflag_co      6991 non-null   int64
#  4   koi_fpflag_ec      6991 non-null   int64
#  5   koi_period         6991 non-null   float64
#  6   koi_period_err1    6991 non-null   float64
#  7   koi_period_err2    6991 non-null   float64
#  8   koi_time0bk        6991 non-null   float64
#  9   koi_time0bk_err1   6991 non-null   float64
#  10  koi_time0bk_err2   6991 non-null   float64
#  11  koi_impact         6991 non-null   float64
#  12  koi_impact_err1    6991 non-null   float64
#  13  koi_impact_err2    6991 non-null   float64
#  14  koi_duration       6991 non-null   float64
#  15  koi_duration_err1  6991 non-null   float64
#  16  koi_duration_err2  6991 non-null   float64
#  17  koi_depth          6991 non-null   float64
#  18  koi_depth_err1     6991 non-null   float64
#  19  koi_depth_err2     6991 non-null   float64
#  20  koi_prad           6991 non-null   float64
#  21  koi_prad_err1      6991 non-null   float64
#  22  koi_prad_err2      6991 non-null   float64
#  23  koi_teq            6991 non-null   int64
#  24  koi_insol          6991 non-null   float64
#  25  koi_insol_err1     6991 non-null   float64
#  26  koi_insol_err2     6991 non-null   float64
#  27  koi_model_snr      6991 non-null   float64
#  28  koi_tce_plnt_num   6991 non-null   int64
#  29  koi_steff          6991 non-null   int64
#  30  koi_steff_err1     6991 non-null   int64
#  31  koi_steff_err2     6991 non-null   int64
#  32  koi_slogg          6991 non-null   float64
#  33  koi_slogg_err1     6991 non-null   float64
#  34  koi_slogg_err2     6991 non-null   float64
#  35  koi_srad           6991 non-null   float64
#  36  koi_srad_err1      6991 non-null   float64
#  37  koi_srad_err2      6991 non-null   float64
#  38  ra                 6991 non-null   float64
#  39  dec                6991 non-null   float64
#  40  koi_kepmag         6991 non-null   float64
# dtypes: float64(31), int64(9), object(1)
# memory usage: 2.2+ MB

# %% [markdown]
# # Select your features (columns)

# %%
#df['ExoplanetConfirmed'] = df['koi_disposition'].apply(lambda x: 2 if x == 'CONFIRMED' else 1 if x == 'CANDIDATE' else 0 )

# %%
df['ExoplanetConfirmed'] = df['koi_disposition'].apply(lambda x: 1 if x == 'CONFIRMED' else 0)

# %%
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  koi_time0bk_err2  koi_impact  koi_impact_err1  \
# 0          0.003520         -0.003520       0.586            0.059
# 1          0.000581         -0.000581       0.969            5.126
# 2          0.000115         -0.000115       1.276            0.115
# 3          0.001130         -0.001130       0.701            0.235
# 4          0.001900         -0.001900       0.762            0.139
#
#    koi_impact_err2  koi_duration  koi_duration_err1  koi_duration_err2  \
# 0           -0.443       4.50700            0.11600           -0.11600
# 1           -0.077       1.78220            0.03410           -0.03410
# 2           -0.092       2.40641            0.00537           -0.00537
# 3           -0.478       1.65450            0.04200           -0.04200
# 4           -0.532       3.14020            0.06730           -0.06730
#
#    koi_depth  koi_depth_err1  koi_depth_err2  koi_prad  koi_prad_err1  \
# 0      874.8            35.5           -35.5      2.83           0.32
# 1    10829.0           171.0          -171.0     14.60           3.92
# 2     8079.2            12.8           -12.8     33.46           8.50
# 3      603.3            16.9           -16.9      2.75           0.88
# 4      686.0            18.7           -18.7      2.77           0.90
#
#    koi_prad_err2  koi_teq  koi_insol  koi_insol_err1  koi_insol_err2  \
# 0          -0.19      443       9.11            2.87           -1.62
# 1          -1.31      638      39.30           31.04          -10.49
# 2          -2.83     1395     891.96          668.95         -230.35
# 3          -0.35     1406     926.16          874.33         -314.24
# 4          -0.30     1160     427.65          420.33         -136.70
#
#    koi_model_snr  koi_tce_plnt_num  koi_steff  koi_steff_err1  koi_steff_err2  \
# 0           25.8                 2       5455              81             -81
# 1           76.3                 1       5853             158            -176
# 2          505.6                 1       5805             157            -174
# 3           40.9                 1       6031             169            -211
# 4           40.2                 2       6046             189            -232
#
#    koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  koi_srad_err1  \
# 0      4.467           0.064          -0.096     0.927          0.105
# 1      4.544           0.044          -0.176     0.868          0.233
# 2      4.564           0.053          -0.168     0.791          0.201
# 3      4.438           0.070          -0.210     1.046          0.334
# 4      4.486           0.054          -0.229     0.972          0.315
#
#    koi_srad_err2         ra        dec  koi_kepmag  ExoplanetConfirmed
# 0         -0.061  291.93423  48.141651      15.347                   1
# 1         -0.078  297.00482  48.134129      15.436                   0
# 2         -0.067  285.53461  48.285210      15.597                   0
# 3         -0.133  288.75488  48.226200      15.509                   1
# 4         -0.105  296.28613  48.224670      15.714                   1

# %%
df.drop(columns=['koi_disposition',
                 'koi_fpflag_nt','koi_fpflag_ss','koi_fpflag_co',
                 'koi_fpflag_ec'], inplace=True)

# %%
df.isna().any()
# Out:
# koi_period            False
# koi_period_err1       False
# koi_period_err2       False
# koi_time0bk           False
# koi_time0bk_err1      False
# koi_time0bk_err2      False
# koi_impact            False
# koi_impact_err1       False
# koi_impact_err2       False
# koi_duration          False
# koi_duration_err1     False
# koi_duration_err2     False
# koi_depth             False
# koi_depth_err1        False
# koi_depth_err2        False
# koi_prad              False
# koi_prad_err1         False
# koi_prad_err2         False
# koi_teq               False
# koi_insol             False
# koi_insol_err1        False
# koi_insol_err2        False
# koi_model_snr         False
# koi_tce_plnt_num      False
# koi_steff             False
# koi_steff_err1        False
# koi_steff_err2        False
# koi_slogg             False
# koi_slogg_err1        False
# koi_slogg_err2        False
# koi_srad              False
# koi_srad_err1         False
# koi_srad_err2         False
# ra                    False
# dec                   False
# koi_kepmag            False
# ExoplanetConfirmed    False
# dtype: bool

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (6991, 37)

# %%
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)

clean_dataset(df)
# Out:
#       koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0      54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1      19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2       1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3       2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4       4.134435     1.050000e-05    -1.050000e-05   172.979370
# ...          ...              ...              ...          ...
# 6986    8.589871     1.846000e-04    -1.846000e-04   132.016100
# 6987    0.527699     1.160000e-07    -1.160000e-07   131.705093
# 6988    1.739849     1.780000e-05    -1.780000e-05   133.001270
# 6989    0.681402     2.430000e-06    -2.430000e-06   132.181750
# 6990    4.856035     6.360000e-05    -6.360000e-05   135.993300
#
#       koi_time0bk_err1  koi_time0bk_err2  koi_impact  koi_impact_err1  \
# 0             0.003520         -0.003520       0.586            0.059
# 1             0.000581         -0.000581       0.969            5.126
# 2             0.000115         -0.000115       1.276            0.115
# 3             0.001130         -0.001130       0.701            0.235
# 4             0.001900         -0.001900       0.762            0.139
# ...                ...               ...         ...              ...
# 6986          0.015700         -0.015700       0.765            0.023
# 6987          0.000170         -0.000170       1.252            0.051
# 6988          0.007690         -0.007690       0.043            0.423
# 6989          0.002850         -0.002850       0.147            0.309
# 6990          0.010800         -0.010800       0.134            0.323
#
#       koi_impact_err2  koi_duration  koi_duration_err1  koi_duration_err2  \
# 0              -0.443       4.50700            0.11600           -0.11600
# 1              -0.077       1.78220            0.03410           -0.03410
# 2              -0.092       2.40641            0.00537           -0.00537
# 3              -0.478       1.65450            0.04200           -0.04200
# 4              -0.532       3.14020            0.06730           -0.06730
# ...               ...           ...                ...                ...
# 6986           -0.541       4.80600            0.63400           -0.63400
# 6987           -0.049       3.22210            0.01740           -0.01740
# 6988           -0.043       3.11400            0.22900           -0.22900
# 6989           -0.147       0.86500            0.16200           -0.16200
# 6990           -0.134       3.07800            0.28300           -0.28300
#
#       koi_depth  koi_depth_err1  koi_depth_err2  koi_prad  koi_prad_err1  \
# 0         874.8            35.5           -35.5      2.83           0.32
# 1       10829.0           171.0          -171.0     14.60           3.92
# 2        8079.2            12.8           -12.8     33.46           8.50
# 3         603.3            16.9           -16.9      2.75           0.88
# 4         686.0            18.7           -18.7      2.77           0.90
# ...         ...             ...             ...       ...            ...
# 6986       87.7            13.0           -13.0      1.11           0.32
# 6987     1579.2             4.6            -4.6     29.35           7.70
# 6988       48.5             5.4            -5.4      0.72           0.24
# 6989      103.6            14.7           -14.7      1.07           0.36
# 6990       76.7            10.8           -10.8      1.05           0.36
#
#       koi_prad_err2  koi_teq  koi_insol  koi_insol_err1  koi_insol_err2  \
# 0             -0.19    443.0       9.11            2.87           -1.62
# 1             -1.31    638.0      39.30           31.04          -10.49
# 2             -2.83   1395.0     891.96          668.95         -230.35
# 3             -0.35   1406.0     926.16          874.33         -314.24
# 4             -0.30   1160.0     427.65          420.33         -136.70
# ...             ...      ...        ...             ...             ...
# 6986          -0.23    929.0     176.40          152.77          -77.60
# 6987          -2.57   2088.0    4500.53         3406.38        -1175.26
# 6988          -0.08   1608.0    1585.81         1537.86         -502.22
# 6989          -0.11   2218.0    5713.41         5675.74        -1836.94
# 6990          -0.12   1266.0     607.42          600.39         -194.33
#
#       koi_model_snr  koi_tce_plnt_num  koi_steff  koi_steff_err1  \
# 0              25.8               2.0     5455.0            81.0
# 1              76.3               1.0     5853.0           158.0
# 2             505.6               1.0     5805.0           157.0
# 3              40.9               1.0     6031.0           169.0
# 4              40.2               2.0     6046.0           189.0
# ...             ...               ...        ...             ...
# 6986            8.4               1.0     5638.0           169.0
# 6987          453.3               1.0     5638.0           139.0
# 6988           10.6               1.0     6119.0           165.0
# 6989           12.3               1.0     6173.0           193.0
# 6990            8.2               1.0     6469.0           158.0
#
#       koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  \
# 0              -81.0      4.467           0.064          -0.096     0.927
# 1             -176.0      4.544           0.044          -0.176     0.868
# 2             -174.0      4.564           0.053          -0.168     0.791
# 3             -211.0      4.438           0.070          -0.210     1.046
# 4             -232.0      4.486           0.054          -0.229     0.972
# ...              ...        ...             ...             ...       ...
# 6986          -152.0      4.296           0.231          -0.189     1.088
# 6987          -166.0      4.529           0.035          -0.196     0.903
# 6988          -220.0      4.444           0.056          -0.224     1.031
# 6989          -236.0      4.447           0.056          -0.224     1.041
# 6990          -225.0      4.385           0.054          -0.216     1.193
#
#       koi_srad_err1  koi_srad_err2         ra        dec  koi_kepmag  \
# 0             0.105         -0.061  291.93423  48.141651      15.347
# 1             0.233         -0.078  297.00482  48.134129      15.436
# 2             0.201         -0.067  285.53461  48.285210      15.597
# 3             0.334         -0.133  288.75488  48.226200      15.509
# 4             0.315         -0.105  296.28613  48.224670      15.714
# ...             ...            ...        ...        ...         ...
# 6986          0.313         -0.228  298.74921  46.973351      14.478
# 6987          0.237         -0.079  297.18875  47.093819      14.082
# 6988          0.341         -0.114  286.50937  47.163219      14.757
# 6989          0.341         -0.114  294.16489  47.176281      15.385
# 6990          0.410         -0.137  297.00977  47.121021      14.826
#
#       ExoplanetConfirmed
# 0                    1.0
# 1                    0.0
# 2                    0.0
# 3                    1.0
# 4                    1.0
# ...                  ...
# 6986                 0.0
# 6987                 0.0
# 6988                 0.0
# 6989                 0.0
# 6990                 0.0
#
# [6991 rows x 37 columns]

# %%
# Set features. This will also be used as your x values.
features = df.drop(columns=['ExoplanetConfirmed'])
target = df.ExoplanetConfirmed.values.reshape(-1,1)

# %%
print(features.shape, target.shape)
# Out:
# (6991, 36) (6991, 1)

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, random_state=1, test_size=.40)

# %%
# Checking if train test split ran correclty
for dataset in [y_train, y_test]:
    print(round(len(dataset)/len(target), 2))
# Out:
# 0.6
# 0.4

# %%
X_train.head()
# Out:
#       koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 748     2.240487     3.670000e-06    -3.670000e-06   137.824770
# 2030   35.583497     4.630000e-05    -4.630000e-05   189.035620
# 5144    4.462553     3.910000e-05    -3.910000e-05   133.649770
# 5746    1.583335     5.590000e-07    -5.590000e-07   132.377894
# 2352    9.521645     8.950000e-06    -8.950000e-06   177.484839
#
#       koi_time0bk_err1  koi_time0bk_err2  koi_impact  koi_impact_err1  \
# 748           0.001370         -0.001370       0.461            0.459
# 2030          0.001000         -0.001000       0.001            0.416
# 5144          0.008510         -0.008510       0.004            0.102
# 5746          0.000290         -0.000290       0.781            0.220
# 2352          0.000726         -0.000726       0.023            0.338
#
#       koi_impact_err2  koi_duration  koi_duration_err1  koi_duration_err2  \
# 748            -0.252        1.3988             0.0448            -0.0448
# 2030           -0.001        3.9885             0.0372            -0.0372
# 5144           -0.004       14.0957             0.0707            -0.0707
# 5746           -0.039        4.4854             0.0191            -0.0191
# 2352           -0.023        2.3569             0.0279            -0.0279
#
#       koi_depth  koi_depth_err1  koi_depth_err2  koi_prad  koi_prad_err1  \
# 748       436.3            14.7           -14.7      1.22           0.07
# 2030      937.6            11.8           -11.8      2.03           0.12
# 5144    22720.0           183.0          -183.0     52.74          29.74
# 5746   177070.0           565.0          -565.0     52.00          15.45
# 2352     1491.3            20.2           -20.2      2.16           0.12
#
#       koi_prad_err2  koi_teq  koi_insol  koi_insol_err1  koi_insol_err2  \
# 748           -0.06      837     115.98           23.82          -19.09
# 2030          -0.09      408       6.54            1.41           -1.04
# 5144         -16.02     1795    2458.34         4318.08        -1370.94
# 5746          -6.60     1548    1362.14         1216.03         -453.76
# 2352          -0.12      495      14.20            2.75           -2.58
#
#       koi_model_snr  koi_tce_plnt_num  koi_steff  koi_steff_err1  \
# 748            33.8                 1       4198              83
# 2030           90.8                 1       4894              97
# 5144          140.9                 1       4847             147
# 5746          368.8                 1       5846             175
# 2352           79.2                 2       4041              72
#
#       koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  \
# 748              -83      4.689           0.023          -0.028     0.574
# 2030             -97      4.637           0.015          -0.042     0.684
# 5144            -110      3.277           0.325          -0.325     3.619
# 5746            -192      4.472           0.065          -0.195     0.953
# 2352             -88      4.697           0.024          -0.027     0.567
#
#       koi_srad_err1  koi_srad_err2         ra        dec  koi_kepmag
# 748           0.032         -0.028  290.82602  44.184109      15.224
# 2030          0.041         -0.031  297.27188  43.333309      12.968
# 5144          2.041         -1.099  296.97522  47.886551      14.673
# 5746          0.283         -0.121  286.78952  45.271381      14.932
# 2352          0.031         -0.031  296.11258  39.978779      14.804

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
from sklearn.preprocessing import MinMaxScaler
X_minmax = MinMaxScaler().fit(X_train)
y_minmax = MinMaxScaler().fit(y_train)

X_train_minmax = X_minmax.transform(X_train)
X_test_minmax = X_minmax.transform(X_test)
y_train_minmax = y_minmax.transform(y_train)
y_test_minmax = y_minmax.transform(y_test)

# %% [markdown]
# # Train the Model

# %%
# Create a LinearRegression model and fit it to the scaled training data
### BEGIN SOLUTION
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train_minmax, y_train_minmax)
model.fit(X_test_minmax, y_test_minmax)
### END SOLUTION
# Out:
# LinearRegression()

# %%
print(f"Training Data Score: {model.score(X_train_minmax, y_train)}")
print(f"Testing Data Score: {model.score(X_test_minmax, y_test)}")
# Out:
# Training Data Score: 0.27183538965298104
# Testing Data Score: 0.2648592071807313

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Evaluation function

def evaluation(y_true, y_pred):
    
# Print Accuracy, Recall, F1 Score, and Precision metrics.
    print('Evaluation Metrics:')
    print('Accuracy: ' + str(metrics.accuracy_score(y_test, y_pred)))
    print('Recall: ' + str(metrics.recall_score(y_test, y_pred)))
    print('F1 Score: ' + str(metrics.f1_score(y_test, y_pred)))
    print('Precision: ' + str(metrics.precision_score(y_test, y_pred)))
    
# Print Confusion Matrix
    print('\nConfusion Matrix:')
    print(' TN,  FP, FN, TP')
    print(confusion_matrix(y_true, y_pred).ravel())
    
# Function Prints best parameters for GridSearchCV
def print_results(results):
    print('Best Parameters: {}\n'.format(results.best_params_))

# %%
# Logistic Regression Model
lr = LogisticRegression(C=100, max_iter=200, class_weight='balanced')

# Fitting Model to the train set
lr.fit(X_train, y_train)

# Predicting on the test set
y_pred = lr.predict(X_test)

# Evaluating model
evaluation(y_test, y_pred)
# Out:
# Evaluation Metrics:
# Accuracy: 0.7425813371469432
# Recall: 0.8492957746478873
# F1 Score: 0.6261682242990655
# Precision: 0.49588815789473684
#
# Confusion Matrix:
#  TN,  FP, FN, TP
# [1474  613  107  603]
# C:\Users\sampo\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Instantiate model
forest = RandomForestClassifier(n_estimators=10, criterion='gini')
#forest = RandomForestClassifier(n_estimators=100, criterion='gini')
# Fitting Model to the train set
forest.fit(X_train, y_train)
# Predicting on the test set
y_pred = forest.predict(X_test)

# Evaluating model
evaluation(y_test, y_pred)
# Out:
# Evaluation Metrics:
# Accuracy: 0.876296031462281
# Recall: 0.676056338028169
# F1 Score: 0.7350689127105666
# Precision: 0.8053691275167785
#
# Confusion Matrix:
#  TN,  FP, FN, TP
# [1971  116  230  480]

# %%
knn = KNeighborsClassifier(leaf_size=8, metric='manhattan',weights='uniform')

# Fitting Model to the train set
knn.fit(X_train, y_train)

# Predicting on the test set
y_pred = knn.predict(X_test)

# Evaluating model
evaluation(y_test, y_pred)
# Out:
# Evaluation Metrics:
# Accuracy: 0.8055058991776903
# Recall: 0.6408450704225352
# F1 Score: 0.6258596973865199
# Precision: 0.6115591397849462
#
# Confusion Matrix:
#  TN,  FP, FN, TP
# [1798  289  255  455]

# %%
# Create the GridSearchCV model
# GridSearch Parameters
parameters = {
    'n_estimators': [5, 50, 100, 150, 200],
    'max_depth': list(range(1, 11)),
    'criterion':['gini','entropy'],
    'max_features': list(range(1,20)),
    'oob_score':[False,True],
}

# %%
# Train the model with GridSearch
#

grid = GridSearchCV(forest, parameters, cv=5, verbose=1, n_jobs=-1)

grid.fit(X_train, y_train)
y_test_grid = grid.predict(X_test)

# # Evaluating model
evaluation(y_test, y_pred)
# Out:
# Fitting 5 folds for each of 3800 candidates, totalling 19000 fits
# Evaluation Metrics:
# Accuracy: 0.876296031462281
# Recall: 0.676056338028169
# F1 Score: 0.7350689127105666
# Precision: 0.8053691275167785
#
# Confusion Matrix:
#  TN,  FP, FN, TP
# [1971  116  230  480]

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'criterion': 'entropy', 'max_depth': 10, 'max_features': 15, 'n_estimators': 100, 'oob_score': False}
# 0.888648550240228

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'bestmodel.sav'
joblib.dump(your_model, filename)
